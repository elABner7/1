# %% [markdown]
# ##**"PROBABILIDAD Y ESTADISTICA ☕"**
#
# Bienvenidos a estos mis apuntes de la materia de probabilidad y estadistica.
# ---
#
# Ya que este cuatri es una batalla a muerte creada por el profe no me queda mas remedio que echarle ganas a esto, pasenle y disfruten de las notas que me invente 2hrs antes de entregarlo.
#
# ---
#
# #LOGICA
#
# En esta materia una de las cosas mas necesarias es la logica, asi como definición rapida la logica es **raciocinio a simple vista**.
#
# La logica nos lleva a la **observación y al pensamiento critico**.
#
# ---
#
# #¡PENSAMIENTO CRITICO!
#
# **Según la SEP:**
#
# El **pensamiento critico** es unconjunto de habilidades cognitivas, dentro de las cuales se consideran como esenciales a la interpretación, el análisis, la evaluación, la inferencia, la explicación y la autorregulación.
#
# **Definición que le entendí al profe:**
#
# El pensamiento critico es **cuestionar todo** todito todo: lo que escucho, lo que digo, lo que aprendo etc...
#
# Volviendo a lo de la logica sin tener que hacer calculos podemos poder obtener afirmaciones o negaciones **(Axiomas o Falacias)**
#
# ---
#
# #ESTADISTICA
#
# **A ver A ver ¿Que es la estadistica?**
#
# **Según la INEGI:**
#
# La **estadística** es una rama de las Matemáticas que, a través de diversas metodologías y técnicas, se encarga de la **recolección y organización de datos** acerca de personas, sucesos o cosas. Asimismo, facilita su análisis e interpretación, con el fin de obtener conclusiones.
#
# **Mi definición**
#
# Es la rama de las mates que gracias a la recolección de datos se pued dar a interpretar la informacion por medio de graficos etc... y dar una conclusión.
#
# ---
#
# **Estadística descriptiva**
#
# Se utiliza para **describir** las características básicas de un conjunto de datos, como su tamaño, distribución, tendencia central, variabilidad y forma. Se utiliza para organizar, sintetizar y describir información de una manera fácil y rápida.
#
# **Estadística inferencial**
#
# Se utiliza para sacar **conclusiones y hacer predicciones** sobre una población o fenómeno más grande en función de una muestra de datos. Se aplica cuando se realiza un muestreo, es decir, cuando se estudia una parte de la población.
#
# #PROBABILIDAD
#
# **Despues... ¿Que chuchas es probabilidad?**
#
# **Según la IA:**
#
# La **probabilidad** es una rama de las matemáticas que se ocupa del estudio de la incertidumbre y los **resultados posibles de un evento** o experimento aleatorio.
#
# En términos simples, la probabilidad mide la posibilidad de que ocurra un evento dentro de un conjunto de posibles resultados.
#
# **Mi definición:**
#
# Es la rama de la ciencia que estudia eventos futuros apoyandose y utilizando herramientas "(como la estadistica)" para **intentar predecir** dichos eventos.
#
# ---
#
# #TEORIA DE CONJUNTOS
# **¿Que es esa cosa rara de teoria de conjuntos?**
#
# La teoría de conjuntos es una rama de las matemáticas que estudia las propiedades y relaciones de los conjuntos, es decir, colecciones de objetos. Se considera un sistema fundacional de las matemáticas, ya que permite construir otros objetos y estructuras, como los números, las figuras geométricas y las funciones.
#
# El matemático ruso Georg Cantor (1845-1918) es el principal responsable del desarrollo de la teoría de conjuntos. Sus descubrimientos sobre los conjuntos infinitos fueron revolucionarios, ya que demostró que existen infinitos de diferentes tamaños.
#
# ---
#
# #TEORIA DEL CAOS 👽
#
# «Si algo nos ha enseñado la historia de la evolución, es que la vida no puede contenerse.» El Dr. Ian Malcolm (29 de junio de 1955) es un matemático y conferencista judío-estadounidense especializado en el campo de la teoría del caos.
#
# La teoría del caos es una rama de la ciencia que estudia el comportamiento de sistemas complejos y dinámicos no lineales. Esta teoría explica por qué es imposible predecir con precisión el comportamiento futuro de algunos sistemas.
#
# La teoría del caos se aplica en diversas disciplinas, como la física, la matemática, la biología, la meteorología y la economía.
#
# El meteorólogo y matemático **Edward Lorenz** descubrió la teoría del caos en 1961.
#
# **EFECTO MARIPOSA**
#
# “Una mariposa bate las alas en Pekín y en New York llueve.” Dr. Ian Malcolm.
#
# Pequeños cambios en las condiciones iniciales pueden producir grandes efectos en un sistema

# %% [markdown]
# ![imagen_2025-01-11_011823210.png](data:image/png;base64,...)

# %% [markdown]
# #**Ejemplo práctico:**
#
# Un administrador de red analiza el tráfico generado por direcciones IP en una red empresarial y detecta que el 30% del tráfico proviene de una única IP.
# Conclusión: Se descubrió que esa IP corresponde a un ataque DDoS.
#
#  Al limitar las conexiones desde esa dirección, se estabilizó el tráfico de la red.
#
# ---
#
# **PLANTEAMIENTO:**
#
# Estamos hablando del tráfico de red, el administrador dispone de varias redes en uno solo, por lo tanto varias "IP"
# Ahora hablamos que en una sola IP tenemos un 30%
# Lo cuál corresponde a un 0.30 de probabilidad de que el paquete de datos provenga de esa IP
# Lo normal sería que las redes se distribuyan de manera equitativa, por lo tanto el tráfico también.
#
# Se llega a la conclusión de que hay una anomalía con base a los datos existentes y los eventos que se esperan.

# %% [markdown]
# ![1.png](data:image/png;base64,...)![TRAFICO.png](data:image/png;base64,...)

# %% [markdown]
# **CONCLUSIÓN**
#
# En estadística nos basamos en los datos que tenemos de igual manera, si tenemos un 30% en una sola IP, se detecta la anomalía
# Entonces para poder estabilizar el tráfico se haría un debido recorte o limitación de redes.
